# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Đồ án chuyên ngành KHDL/Dataset/Vcb.csv')
df
# Out:
#             DATE  CLOSE TICKER  OPEN  HIGH   LOW   VOLUME  HELPER  Revenue  \
# 0     30/06/2009   60.0    VCB  60.0  60.0  60.0   294070    3246    12732
# 1       1/7/2009   60.5    VCB  63.0  63.0  59.5  6248390    3245    31243
# 2       2/7/2009   58.0    VCB  59.5  60.0  57.5  1515670    3244    40403
# 3       3/7/2009   56.0    VCB  56.5  57.0  56.0   899720    3243    42103
# 4       6/7/2009   58.5    VCB  56.0  58.5  56.0  1571740    3242    30757
# ...          ...    ...    ...   ...   ...   ...      ...     ...      ...
# 2637  24/06/2022   75.0    VCB  76.2  76.3  74.6   648600       5    24144
# 2638  27/06/2022   74.9    VCB  75.5  76.0  74.8   862500       4    43800
# 2639  28/06/2022   76.3    VCB  75.0  77.0  74.8  1100000       3    45779
# 2640  29/06/2022   75.5    VCB  75.8  75.9  75.3   847500       2    37398
# 2641  30/06/2022   74.8    VCB  75.5  76.0  74.8   678400       1    37749
#
#       Profit_Before_Tax  Net_Profit  Profit_Margin  Customer_Loans  \
# 0                  4068        6213      48.798303           23360
# 1                  4463        1411       4.516212            6582
# 2                  8629        1807       4.472440           23869
# 3                  1082        1392       3.306178           34905
# 4                  4843         926       3.010697           27201
# ...                 ...         ...            ...             ...
# 2637               9192        3921      16.240060           39580
# 2638               9727        2322       5.301370           14430
# 2639               5852        7934      17.331091           13615
# 2640               5718        7575      20.255094           19816
# 2641               1806        4972      13.171210           24632
#
#       Loans_from_Other_Organizations  Number_of_Customers  \
# 0                              14092                 2705
# 1                              14863                 1090
# 2                              15019                 7832
# 3                               9246                 3424
# 4                               2930                 9234
# ...                              ...                  ...
# 2637                            8279                 1985
# 2638                           10040                 8403
# 2639                           15608                 4143
# 2640                           17877                 7913
# 2641                           19561                 3035
#
#      Customer_Classification
# 0                     Retail
# 1                        SME
# 2                  Corporate
# 3                     Retail
# 4                  Corporate
# ...                      ...
# 2637               Corporate
# 2638                  Retail
# 2639                     SME
# 2640                  Retail
# 2641               Corporate
#
# [2642 rows x 16 columns]

# %%
# hiển thị số dòng và số cột của dữ liệu

rows, columns = df.shape

print(f"Number Of Rows : {rows}")
print(f"Number Of Columns : {columns}")
# Out:
# Number Of Rows : 2642
# Number Of Columns : 16

# %%
# Hiển thị mẫu dữ liệu

df.sample(1).iloc[0]
# Out:
# DATE                              16/07/2014
# CLOSE                                   26.1
# TICKER                                   VCB
# OPEN                                    25.8
# HIGH                                    26.2
# LOW                                     25.8
# VOLUME                                392220
# HELPER                                  1988
# Revenue                                38582
# Profit_Before_Tax                       1019
# Net_Profit                              5278
# Profit_Margin                      13.679954
# Customer_Loans                         39885
# Loans_from_Other_Organizations         10499
# Number_of_Customers                     9634
# Customer_Classification            Corporate
# Name: 654, dtype: object

# %%
# Xuất ra dữ liệu
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2642 entries, 0 to 2641
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DATE                            2642 non-null   object
#  1   CLOSE                           2642 non-null   float64
#  2   TICKER                          2642 non-null   object
#  3   OPEN                            2642 non-null   float64
#  4   HIGH                            2642 non-null   float64
#  5   LOW                             2642 non-null   float64
#  6   VOLUME                          2642 non-null   int64
#  7   HELPER                          2642 non-null   int64
#  8   Revenue                         2642 non-null   int64
#  9   Profit_Before_Tax               2642 non-null   int64
#  10  Net_Profit                      2642 non-null   int64
#  11  Profit_Margin                   2642 non-null   float64
#  12  Customer_Loans                  2642 non-null   int64
#  13  Loans_from_Other_Organizations  2642 non-null   int64
#  14  Number_of_Customers             2642 non-null   int64
#  15  Customer_Classification         2642 non-null   object
# dtypes: float64(5), int64(8), object(3)
# memory usage: 330.4+ KB

# %%
# Xuất ra bản kê
df.describe()
# Out:
#              CLOSE         OPEN         HIGH          LOW        VOLUME  \
# count  2642.000000  2642.000000  2642.000000  2642.000000  2.642000e+03
# mean     51.557531    51.532481    52.178632    50.917226  1.105530e+06
# std      17.431675    17.427062    17.635724    17.175753  9.199297e+05
# min      23.000000    23.000000    23.100000    22.600000  1.895000e+04
# 25%      37.150000    37.200000    37.500000    36.900000  4.613625e+05
# 50%      48.000000    48.000000    48.800000    47.400000  8.686400e+05
# 75%      66.336750    66.119000    67.000000    65.504000  1.490000e+06
# max      95.800000    95.800000    96.000000    92.600000  8.010000e+06
#
#             HELPER       Revenue  Profit_Before_Tax   Net_Profit  \
# count  2642.000000   2642.000000        2642.000000  2642.000000
# mean   1459.811885  29983.992808        5499.935276  4735.579864
# std     963.422586  11602.479971        2606.806296  2426.413250
# min       1.000000  10043.000000        1001.000000   504.000000
# 25%     661.250000  19777.250000        3235.250000  2656.000000
# 50%    1321.500000  30114.500000        5495.000000  4757.000000
# 75%    1981.750000  40076.000000        7729.250000  6817.500000
# max    3246.000000  49979.000000        9997.000000  8999.000000
#
#        Profit_Margin  Customer_Loans  Loans_from_Other_Organizations  \
# count    2642.000000     2642.000000                     2642.000000
# mean       19.107545    22292.774413                    10573.419001
# std        14.282575    10204.573532                     5493.715167
# min         1.037699     5005.000000                     1002.000000
# 25%         8.919645    13208.250000                     5778.500000
# 50%        15.997090    22229.000000                    10570.500000
# 75%        24.821189    31241.000000                    15324.250000
# max        85.183741    39997.000000                    19982.000000
#
#        Number_of_Customers
# count          2642.000000
# mean           5463.739591
# std            2575.883075
# min            1001.000000
# 25%            3266.000000
# 50%            5375.500000
# 75%            7701.500000
# max            9995.000000

# %%
df.nunique()
# Out:
# DATE                              2642
# CLOSE                              803
# TICKER                               1
# OPEN                               798
# HIGH                               808
# LOW                                815
# VOLUME                            2350
# HELPER                            2642
# Revenue                           2558
# Profit_Before_Tax                 2294
# Net_Profit                        2278
# Profit_Margin                     2642
# Customer_Loans                    2544
# Loans_from_Other_Organizations    2457
# Number_of_Customers               2282
# Customer_Classification              3
# dtype: int64

# %%
#Xuất ra 5 dòng trên cùng
df.head()
# Out:
#          DATE  CLOSE TICKER  OPEN  HIGH   LOW   VOLUME  HELPER  Revenue  \
# 0  30/06/2009   60.0    VCB  60.0  60.0  60.0   294070    3246    12732
# 1    1/7/2009   60.5    VCB  63.0  63.0  59.5  6248390    3245    31243
# 2    2/7/2009   58.0    VCB  59.5  60.0  57.5  1515670    3244    40403
# 3    3/7/2009   56.0    VCB  56.5  57.0  56.0   899720    3243    42103
# 4    6/7/2009   58.5    VCB  56.0  58.5  56.0  1571740    3242    30757
#
#    Profit_Before_Tax  Net_Profit  Profit_Margin  Customer_Loans  \
# 0               4068        6213      48.798303           23360
# 1               4463        1411       4.516212            6582
# 2               8629        1807       4.472440           23869
# 3               1082        1392       3.306178           34905
# 4               4843         926       3.010697           27201
#
#    Loans_from_Other_Organizations  Number_of_Customers Customer_Classification
# 0                           14092                 2705                  Retail
# 1                           14863                 1090                     SME
# 2                           15019                 7832               Corporate
# 3                            9246                 3424                  Retail
# 4                            2930                 9234               Corporate

# %%
df = df.drop(columns=['TICKER'])
df
# Out:
#             DATE  CLOSE  OPEN  HIGH   LOW   VOLUME  HELPER  Revenue  \
# 0     30/06/2009   60.0  60.0  60.0  60.0   294070    3246    12732
# 1       1/7/2009   60.5  63.0  63.0  59.5  6248390    3245    31243
# 2       2/7/2009   58.0  59.5  60.0  57.5  1515670    3244    40403
# 3       3/7/2009   56.0  56.5  57.0  56.0   899720    3243    42103
# 4       6/7/2009   58.5  56.0  58.5  56.0  1571740    3242    30757
# ...          ...    ...   ...   ...   ...      ...     ...      ...
# 2637  24/06/2022   75.0  76.2  76.3  74.6   648600       5    24144
# 2638  27/06/2022   74.9  75.5  76.0  74.8   862500       4    43800
# 2639  28/06/2022   76.3  75.0  77.0  74.8  1100000       3    45779
# 2640  29/06/2022   75.5  75.8  75.9  75.3   847500       2    37398
# 2641  30/06/2022   74.8  75.5  76.0  74.8   678400       1    37749
#
#       Profit_Before_Tax  Net_Profit  Profit_Margin  Customer_Loans  \
# 0                  4068        6213      48.798303           23360
# 1                  4463        1411       4.516212            6582
# 2                  8629        1807       4.472440           23869
# 3                  1082        1392       3.306178           34905
# 4                  4843         926       3.010697           27201
# ...                 ...         ...            ...             ...
# 2637               9192        3921      16.240060           39580
# 2638               9727        2322       5.301370           14430
# 2639               5852        7934      17.331091           13615
# 2640               5718        7575      20.255094           19816
# 2641               1806        4972      13.171210           24632
#
#       Loans_from_Other_Organizations  Number_of_Customers  \
# 0                              14092                 2705
# 1                              14863                 1090
# 2                              15019                 7832
# 3                               9246                 3424
# 4                               2930                 9234
# ...                              ...                  ...
# 2637                            8279                 1985
# 2638                           10040                 8403
# 2639                           15608                 4143
# 2640                           17877                 7913
# 2641                           19561                 3035
#
#      Customer_Classification
# 0                     Retail
# 1                        SME
# 2                  Corporate
# 3                     Retail
# 4                  Corporate
# ...                      ...
# 2637               Corporate
# 2638                  Retail
# 2639                     SME
# 2640                  Retail
# 2641               Corporate
#
# [2642 rows x 15 columns]

# %%
# Xác định các cột không phải số
non_numeric_cols = df.select_dtypes(exclude=['number']).columns
non_numeric_cols
# Out:
# Index(['DATE', 'Customer_Classification'], dtype='object')

# %%
# Chuyển đổi cột DATE thành kiểu dữ liệu datetime
df['DATE'] = pd.to_datetime(df['DATE'])

# Chỉ tính tương quan cho các cột số
df_numeric = df.drop(columns=non_numeric_cols)
df_numeric.corr()
# Out:
#                                    CLOSE      OPEN      HIGH       LOW  \
# CLOSE                           1.000000  0.998402  0.999347  0.999094
# OPEN                            0.998402  1.000000  0.999151  0.999246
# HIGH                            0.999347  0.999151  1.000000  0.998951
# LOW                             0.999094  0.999246  0.998951  1.000000
# VOLUME                          0.404266  0.399903  0.411328  0.392648
# HELPER                         -0.750193 -0.748363 -0.748623 -0.750278
# Revenue                        -0.024934 -0.025111 -0.025690 -0.024945
# Profit_Before_Tax              -0.021047 -0.020425 -0.021151 -0.020317
# Net_Profit                     -0.007282 -0.007681 -0.007572 -0.006815
# Profit_Margin                   0.008206  0.008129  0.008431  0.008227
# Customer_Loans                  0.008013  0.007831  0.008306  0.007722
# Loans_from_Other_Organizations -0.004102 -0.006404 -0.004902 -0.005173
# Number_of_Customers            -0.015970 -0.014114 -0.016298 -0.014871
#
#                                   VOLUME    HELPER   Revenue  \
# CLOSE                           0.404266 -0.750193 -0.024934
# OPEN                            0.399903 -0.748363 -0.025111
# HIGH                            0.411328 -0.748623 -0.025690
# LOW                             0.392648 -0.750278 -0.024945
# VOLUME                          1.000000 -0.450811 -0.013433
# HELPER                         -0.450811  1.000000  0.006727
# Revenue                        -0.013433  0.006727  1.000000
# Profit_Before_Tax              -0.016579  0.014958 -0.016836
# Net_Profit                     -0.035902  0.009680  0.003892
# Profit_Margin                  -0.012557 -0.005328 -0.599832
# Customer_Loans                  0.009404 -0.022950 -0.011731
# Loans_from_Other_Organizations  0.015358  0.005876  0.004588
# Number_of_Customers            -0.045662  0.003735  0.017565
#
#                                 Profit_Before_Tax  Net_Profit  Profit_Margin  \
# CLOSE                                   -0.021047   -0.007282       0.008206
# OPEN                                    -0.020425   -0.007681       0.008129
# HIGH                                    -0.021151   -0.007572       0.008431
# LOW                                     -0.020317   -0.006815       0.008227
# VOLUME                                  -0.016579   -0.035902      -0.012557
# HELPER                                   0.014958    0.009680      -0.005328
# Revenue                                 -0.016836    0.003892      -0.599832
# Profit_Before_Tax                        1.000000    0.004120       0.011258
# Net_Profit                               0.004120    1.000000       0.678903
# Profit_Margin                            0.011258    0.678903       1.000000
# Customer_Loans                           0.011033   -0.023781      -0.015738
# Loans_from_Other_Organizations          -0.028840    0.011795       0.008552
# Number_of_Customers                     -0.017503    0.009391      -0.012137
#
#                                 Customer_Loans  \
# CLOSE                                 0.008013
# OPEN                                  0.007831
# HIGH                                  0.008306
# LOW                                   0.007722
# VOLUME                                0.009404
# HELPER                               -0.022950
# Revenue                              -0.011731
# Profit_Before_Tax                     0.011033
# Net_Profit                           -0.023781
# Profit_Margin                        -0.015738
# Customer_Loans                        1.000000
# Loans_from_Other_Organizations        0.016885
# Number_of_Customers                   0.029173
#
#                                 Loans_from_Other_Organizations  \
# CLOSE                                                -0.004102
# OPEN                                                 -0.006404
# HIGH                                                 -0.004902
# LOW                                                  -0.005173
# VOLUME                                                0.015358
# HELPER                                                0.005876
# Revenue                                               0.004588
# Profit_Before_Tax                                    -0.028840
# Net_Profit                                            0.011795
# Profit_Margin                                         0.008552
# Customer_Loans                                        0.016885
# Loans_from_Other_Organizations                        1.000000
# Number_of_Customers                                   0.022109
#
#                                 Number_of_Customers
# CLOSE                                     -0.015970
# OPEN                                      -0.014114
# HIGH                                      -0.016298
# LOW                                       -0.014871
# VOLUME                                    -0.045662
# HELPER                                     0.003735
# Revenue                                    0.017565
# Profit_Before_Tax                         -0.017503
# Net_Profit                                 0.009391
# Profit_Margin                             -0.012137
# Customer_Loans                             0.029173
# Loans_from_Other_Organizations             0.022109
# Number_of_Customers                        1.000000

# %%
#Trực quan hóa về bảng tương quan
plt.figure(figsize=(10, 8))
corr = df_numeric.corr()
sns.heatmap(corr, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
# Kiểm tra các giá trị Null trong bộ dữ liệu
df.isnull().sum()
# Out:
# DATE                              0
# CLOSE                             0
# OPEN                              0
# HIGH                              0
# LOW                               0
# VOLUME                            0
# HELPER                            0
# Revenue                           0
# Profit_Before_Tax                 0
# Net_Profit                        0
# Profit_Margin                     0
# Customer_Loans                    0
# Loans_from_Other_Organizations    0
# Number_of_Customers               0
# Customer_Classification           0
# dtype: int64

# %%
#Kiểm tra các dòng có bị trùng hay không
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Kiểm tra các giá trị ngoại lai trong bộ dữ liệu

# %%
# Các cột
print(df.columns)
# Out:
# Index(['DATE', 'CLOSE', 'OPEN', 'HIGH', 'LOW', 'VOLUME', 'HELPER', 'Revenue',
#        'Profit_Before_Tax', 'Net_Profit', 'Profit_Margin', 'Customer_Loans',
#        'Loans_from_Other_Organizations', 'Number_of_Customers',
#        'Customer_Classification'],
#       dtype='object')

# %%
# Kiểm tra theo biểu đồ Boxplot ở cột Revenue
sns.boxplot(x = df.Revenue, color='teal')
plt.show()

# %% [markdown]
# Không xuất hiện dấu chấm chứng tỏ không có dữ liệu ngoại lai

# %%
# Kiểm tra theo biểu đồ Boxplot ở cột Profit_Before_Tax
sns.boxplot(x = df.Profit_Before_Tax, color='teal')
plt.show()

# %% [markdown]
# Không xuất hiện dấu chấm chứng tỏ không có dữ liệu ngoại lai

# %%
# Kiểm tra theo biểu đồ Boxplot ở cột Net_Profit
sns.boxplot(x = df.Net_Profit, color='teal')
plt.show()

# %% [markdown]
# Không xuất hiện dấu chấm chứng tỏ không có dữ liệu ngoại lai

# %% [markdown]
# Xem xét các chỉ số lợi nhuận như doanh thu, lợi nhuận trước thuế, lợi nhuận ròng và biên lợi nhuận.Xem xét các khoản nợ của ngân hàng, bao gồm nợ vay từ khách hàng và nợ vay từ các tổ chức khác. Thông tin về số lượng và phân loại khách hàng, Trực quan hóa, (xây dựng thực nghiệm)

# %% [markdown]
# * Xem xét các chỉ số lợi nhuận như doanh thu, lợi nhuận trước thuế, lợi nhuận ròng và biên lợi nhuận.

# %%
# Nhóm theo năm
data_grouped_by_year = df.groupby(df['DATE'].dt.year)

# %%
# Tính toán tổng Doanh thu theo năm(Revenue)
revenue_by_year = data_grouped_by_year['Revenue'].sum()
print("Doanh thu theo năm:")
print(revenue_by_year)
# Out:
# Doanh thu theo năm:
# DATE
# 2009    3922851
# 2010    7549976
# 2011    6616244
# 2014    5274531
# 2015    7437600
# 2016    7300397
# 2017    7835207
# 2018    7359725
# 2019    7409497
# 2020    7561578
# 2021    7401359
# 2022    3548744
# Name: Revenue, dtype: int64

# %%
# Biểu đồ đường cho Doanh thu theo năm(Revenue)
revenue_by_year.plot(kind='line',marker='o', label='Doanh thu', color='b')

plt.xlabel('Năm')
plt.ylabel('Giá trị')
plt.title('Biểu đồ đường Doanh thu theo năm(Revenue)')
plt.legend()
plt.show()

# %%
# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
width = 0.5
bar1 = ax.bar(revenue_by_year.index, revenue_by_year, width, label='Doanh thu',color='b')

# Set the labels and title
ax.set_xlabel('Năm')
ax.set_ylabel('Giá trị')
ax.set_title('Biểu đồ cột Doanh thu theo năm(Revenue)')
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
pie_chart = ax.pie(revenue_by_year, labels=revenue_by_year.index, autopct='%1.1f%%', startangle=90)

#Biểu đồ hình tròn Doanh thu theo năm(Revenue)
ax.set_title('Biểu đồ hình tròn Doanh thu theo năm(Revenue)')
plt.legend(revenue_by_year.index, loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.show()

# %%
# Tính toán tổng Lợi nhuận trước thuế theo năm(Profit_Before_Tax)
profit_before_tax_by_year = data_grouped_by_year['Profit_Before_Tax'].sum()
print("\nLợi nhuận trước thuế theo năm:")
print(profit_before_tax_by_year)
# Out:
# Lợi nhuận trước thuế theo năm:
# DATE
# 2009     732979
# 2010    1397386
# 2011    1270250
# 2014     931125
# 2015    1358174
# 2016    1349658
# 2017    1392309
# 2018    1307311
# 2019    1317258
# 2020    1385436
# 2021    1420322
# 2022     668621
# Name: Profit_Before_Tax, dtype: int64

# %%
# Biểu đồ đường cho Lợi nhuận trước thuế theo năm(Profit Before Tax)
profit_before_tax_by_year.plot(kind='line',marker='o', label='Lợi nhuận trước thuế',color='r')

plt.xlabel('Năm')
plt.ylabel('Giá trị')
plt.title('Biểu đồ đường Lợi nhuận trước thuế theo năm(Profit Before Tax)')
plt.legend()
plt.show()

# %%
# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
width = 0.5
bar2 = ax.bar(profit_before_tax_by_year.index + width, profit_before_tax_by_year, width, label='Lợi nhuận trước thuế',color='r')

# Set the labels and title
ax.set_xlabel('Năm')
ax.set_ylabel('Giá trị')
ax.set_title('Biểu đồ cột Lợi nhuận trước thuế theo năm(Profit Before Tax)')
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
pie_chart = ax.pie(profit_before_tax_by_year, labels=profit_before_tax_by_year.index, autopct='%1.1f%%', startangle=90)

#Biểu đồ hình tròn Lợi nhuận trước thuế theo năm(Profit Before Tax)
ax.set_title('Biểu đồ hình tròn Lợi nhuận trước thuế theo năm(Profit Before Tax)')
plt.legend(profit_before_tax_by_year.index, loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.show()

# %%
# Tính toán Lợi nhuận ròng theo năm(Net_Profit)
net_profit_by_year = data_grouped_by_year['Net_Profit'].sum()
print("\nLợi nhuận ròng theo năm:")
print(net_profit_by_year)
# Out:
# Lợi nhuận ròng theo năm:
# DATE
# 2009     619472
# 2010    1177729
# 2011    1103492
# 2014     819622
# 2015    1202422
# 2016    1104528
# 2017    1161764
# 2018    1227942
# 2019    1176790
# 2020    1186683
# 2021    1139574
# 2022     591384
# Name: Net_Profit, dtype: int64

# %%
# Biểu đồ đường cho lợi nhuận ròng(Net_Profit)
net_profit_by_year.plot(kind='line',marker='o', label='Lợi nhuận ròng',color='green')

plt.xlabel('Năm')
plt.ylabel('Giá trị')
plt.title('Biểu đồ đường lợi nhuận ròng(Net_Profit)')
plt.legend()
plt.show()

# %%
# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
width = 0.5
bar3 = ax.bar(net_profit_by_year.index + 2*width, net_profit_by_year, width, label='lợi nhuận ròng',color='green')

# Set the labels and title
ax.set_xlabel('Năm')
ax.set_ylabel('Giá trị')
ax.set_title('Biểu đồ cột lợi nhuận ròng(Net_Profit)')
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
pie_chart = ax.pie(net_profit_by_year, labels=net_profit_by_year.index, autopct='%1.1f%%', startangle=90)

#Biểu đồ hình tròn lợi nhuận ròng(Net_Profit)
ax.set_title('Biểu đồ hình tròn lợi nhuận ròng(Net_Profit)')
plt.legend(net_profit_by_year.index, loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.show()

# %%
# Tính toán tổng Biên lợi nhuận theo năm(Profit_Margin)
profit_margin_by_year = (net_profit_by_year / revenue_by_year) * 100
print("\nBiên lợi nhuận theo năm:")
print(profit_margin_by_year)
# Out:
# Biên lợi nhuận theo năm:
# DATE
# 2009    15.791372
# 2010    15.599109
# 2011    16.678526
# 2014    15.539239
# 2015    16.166801
# 2016    15.129698
# 2017    14.827483
# 2018    16.684618
# 2019    15.882185
# 2020    15.693589
# 2021    15.396821
# 2022    16.664600
# dtype: float64

# %%
# Biểu đồ đường cho biên lợi nhuận theo năm(Profit_Margin)
profit_margin_by_year.plot(kind='line',marker='o', label='Biên lợi nhuận', color='brown')

plt.xlabel('Năm')
plt.ylabel('Giá trị')
plt.title('Biểu đồ đường Biên lợi nhuận theo năm(Profit_Margin)')
plt.legend()
plt.show()

# %%
# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
width = 0.5
bar3 = ax.bar(profit_margin_by_year.index + 2*width, profit_margin_by_year, width, label='Biên lợi nhuận',color='brown')

# Set the labels and title
ax.set_xlabel('Năm')
ax.set_ylabel('Giá trị')
ax.set_title('Biểu đồ đường Biên lợi nhuận theo năm(Profit_Margin)')
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
pie_chart = ax.pie(profit_margin_by_year, labels=profit_margin_by_year.index, autopct='%1.1f%%', startangle=90)

#Biểu đồ hình tròn Biên lợi nhuận theo năm(Profit_Margin)
ax.set_title('Biểu đồ hình tròn Biên lợi nhuận theo năm(Profit_Margin)')
plt.legend(profit_margin_by_year.index, loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.show()

# %% [markdown]
# * Xem xét các khoản nợ của ngân hàng, bao gồm nợ vay từ khách hàng và nợ vay từ các tổ chức khác.

# %%
# Tính toán tổng nợ cho khách hàng vay
customer_loans_by_year = data_grouped_by_year['Customer_Loans'].sum()

# In kết quả
print("\nTổng nợ cho khách hàng vay theo năm:")
print(customer_loans_by_year)
# Out:
# Tổng nợ cho khách hàng vay theo năm:
# DATE
# 2009    2835289
# 2010    5431885
# 2011    5106944
# 2014    3727904
# 2015    5351996
# 2016    5544732
# 2017    5695419
# 2018    5541102
# 2019    5525303
# 2020    5763119
# 2021    5657215
# 2022    2716602
# Name: Customer_Loans, dtype: int64

# %%
# Tính toán tổng nợ vay từ các tổ chức khác
loans_from_other_organizations_by_year = data_grouped_by_year['Loans_from_Other_Organizations'].sum()

print("\nNợ vay từ các tổ chức khác theo năm:")
print(loans_from_other_organizations_by_year)
# Out:
# Nợ vay từ các tổ chức khác theo năm:
# DATE
# 2009    1421444
# 2010    2629738
# 2011    2343173
# 2014    1756398
# 2015    2597992
# 2016    2763697
# 2017    2691136
# 2018    2574502
# 2019    2664730
# 2020    2594326
# 2021    2695968
# 2022    1201869
# Name: Loans_from_Other_Organizations, dtype: int64

# %%
# Biểu đồ đường cho các khoản nợ của ngân hàng
customer_loans_by_year.plot(kind='line',marker='o', label='Tổng nợ cho khách hàng vay',color='green')
loans_from_other_organizations_by_year.plot(kind='line',marker='o', label='Tổng nợ vay từ các tổ chức khác',color='b')

plt.xlabel('Năm')
plt.ylabel('Các khoản nợ của ngân hàng')
plt.title('Biểu đồ đường các khoản nợ của ngân hàng')
plt.legend()
plt.show()

# %%
# Create the bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of the bars
width = 0.35
bar = ax.bar(customer_loans_by_year.index - width/2, customer_loans_by_year, width, label='nợ cho khách hàng vay',color='green')
bar1 = ax.bar(loans_from_other_organizations_by_year.index + width/2, loans_from_other_organizations_by_year, width, label='nợ vay từ các tổ chức khác',color='b')

# Set the labels and title
ax.set_xlabel('Năm')
ax.set_ylabel('Giá trị')
ax.set_title('Biểu đồ cột các khoản nợ của ngân hàng')
ax.legend()
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
pie_chart = ax.pie(customer_loans_by_year, labels=customer_loans_by_year.index, autopct='%1.1f%%', startangle=90)

#Biểu đồ hình tròn nợ cho khách hàng vay
ax.set_title('Biểu đồ hình tròn nợ cho khách hàng vay')
plt.legend(customer_loans_by_year.index, loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
pie_chart = ax.pie(loans_from_other_organizations_by_year, labels=loans_from_other_organizations_by_year.index, autopct='%1.1f%%', startangle=90)

#Biểu đồ hình tròn nợ vay từ các tổ chức khác
ax.set_title('Biểu đồ hình tròn nợ vay từ các tổ chức khác')
plt.legend(loans_from_other_organizations_by_year.index, loc='center left', bbox_to_anchor=(1, 0.5))
plt.tight_layout()
plt.show()

# %% [markdown]
# * Thông tin về số lượng và phân loại khách hàng

# %%
#Tổng số khách hàng
customer_counts = df['Number_of_Customers'].sum()

# Tính toán số lượng khách hàng theo phân loại
customer_classification_counts = df['Customer_Classification'].value_counts()

# In kết quả
print("\nTổng số khách hàng:")
print(customer_counts)

print("\nSố lượng khách hàng theo phân loại:")
print(customer_classification_counts)

# Tính toán số lượng khách hàng theo năm và phân loại
customer_counts_by_year_and_classification = df.groupby([df['DATE'].dt.year, 'Customer_Classification'])['Customer_Classification'].count().unstack()

print("\nSố lượng khách hàng theo năm và phân loại:")
print(customer_counts_by_year_and_classification)
# Out:
# Tổng số khách hàng:
# 14435200
#
# Số lượng khách hàng theo phân loại:
# Customer_Classification
# Corporate    915
# Retail       892
# SME          835
# Name: count, dtype: int64
#
# Số lượng khách hàng theo năm và phân loại:
# Customer_Classification  Corporate  Retail  SME
# DATE
# 2009                            45      38   49
# 2010                            81      86   83
# 2011                            86      73   64
# 2014                            57      57   54
# 2015                            84      79   85
# 2016                            92      83   76
# 2017                            73      96   81
# 2018                            76      91   81
# 2019                           104      70   76
# 2020                            99      78   75
# 2021                            74     100   76
# 2022                            44      41   35

# %%
# Biểu đồ đường cho số lượng và phân loại khách hàng
customer_counts_by_year_and_classification.plot(kind='line',marker='o', label='Tổng nợ cho khách hàng vay')

plt.xlabel('Năm')
plt.ylabel('số lượng')
plt.title('Biểu đồ đường số lượng và phân loại khách hàng ')
plt.legend()
plt.show()
